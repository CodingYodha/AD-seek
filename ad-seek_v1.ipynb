# %%
# ===================================================================
# STEP 0: ENVIRONMENT SETUP
# ===================================================================

# Install all necessary libraries
# !pip install -q "transformers==4.40.1" "datasets==2.18.0" "peft==0.10.0" "accelerate==0.29.3" "bitsandbytes==0.43.1" "trl==0.8.6"
# !pip install -q mne==1.6.0 numpy scipy pandas scikit-learn torch matplotlib seaborn

import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import mne
import numpy as np
import pandas as pd
from scipy.signal import welch
from tqdm.auto import tqdm
import json
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Set Hugging Face cache to the writable directory
os.environ['HF_HOME'] = '/kaggle/working/huggingface'

# Set MNE to use less verbose output
mne.set_log_level('WARNING')

# ===================================================================
# STEP 1: PREPROCESSING & FEATURE EXTRACTION
# ===================================================================

# Define frequency bands
BANDS = {
    'delta': [0.5, 4],
    'theta': [4, 8],
    'alpha': [8, 13],
    'beta': [13, 30],
    'gamma': [30, 45]
}

def extract_eeg_features(eeg_set_path):
    """Extracts Relative Band Power (RBP) and connectivity features from a .set EEG file."""
    try:
        # Load EEG data
        raw = mne.io.read_raw_eeglab(eeg_set_path, preload=True, verbose=False)
        
        # Check if data is empty
        if raw.get_data().shape[1] == 0:
            print(f"Empty data in {os.path.basename(eeg_set_path)}")
            return None
            
        # Apply bandpass filter
        raw.filter(0.5, 45., fir_design='firwin', verbose=False)
        
        sfreq = raw.info['sfreq']
        data = raw.get_data() * 1e6  # Convert to microvolts
        
        # Check for NaN or infinite values
        if np.any(np.isnan(data)) or np.any(np.isinf(data)):
            print(f"NaN or infinite values in {os.path.basename(eeg_set_path)}")
            return None
        
        # Calculate PSD
        freqs, psd = welch(data, sfreq, nperseg=min(int(sfreq*2), data.shape[1]//2))
        
        # Calculate total power and handle zero values
        total_power = np.sum(psd, axis=-1)
        total_power = np.where(total_power == 0, 1e-10, total_power)
        
        # Calculate relative band power features
        rbp_features = {}
        for band, (low, high) in BANDS.items():
            band_indices = (freqs >= low) & (freqs < high)
            if np.any(band_indices):
                band_power = np.sum(psd[:, band_indices], axis=-1)
                rbp = band_power / total_power
                rbp_features[f'rbp_{band}_mean'] = np.mean(rbp)
                rbp_features[f'rbp_{band}_std'] = np.std(rbp)
            else:
                rbp_features[f'rbp_{band}_mean'] = 0.0
                rbp_features[f'rbp_{band}_std'] = 0.0

        # Calculate additional statistical features
        # Channel-wise statistics
        rbp_features['mean_across_channels'] = np.mean(data, axis=0).mean()
        rbp_features['std_across_channels'] = np.std(data, axis=0).mean()
        rbp_features['skewness'] = np.mean([np.mean((channel - np.mean(channel))**3) / (np.std(channel)**3) 
                                          for channel in data if np.std(channel) > 0])
        rbp_features['kurtosis'] = np.mean([np.mean((channel - np.mean(channel))**4) / (np.std(channel)**4) 
                                          for channel in data if np.std(channel) > 0])
        
        all_features = rbp_features
        
        # Check for NaN values in features
        for key, value in all_features.items():
            if np.isnan(value) or np.isinf(value):
                all_features[key] = 0.0
                
        return all_features
        
    except Exception as e:
        print(f"Error processing {os.path.basename(eeg_set_path)}: {e}")
        return None

# Load participant data
try:
    DATA_DIR = "/kaggle/input/open-nuro-dataset/dataset"
    participants_df = pd.read_csv(os.path.join(DATA_DIR, 'participants.tsv'), sep='\t')
    print(f"Loaded {len(participants_df)} participants")
except Exception as e:
    print(f"Error loading participants data: {e}")
    # Create dummy data for testing
    participants_df = pd.DataFrame({
        'participant_id': [f'sub-{i:03d}' for i in range(1, 101)],
        'Group': ['A'] * 50 + ['F'] * 50,
        'age': np.random.randint(50, 80, 100),
        'sex': ['M', 'F'] * 50
    })

# Extract features from all subjects
all_subject_features = []
processed_count = 0

for index, row in tqdm(participants_df.iterrows(), total=len(participants_df), desc="Processing EEG files"):
    subject_id = row['participant_id']
    eeg_file = f"{subject_id}_task-eyesclosed_eeg.set"
    eeg_path = os.path.join(DATA_DIR, subject_id, 'eeg', eeg_file)
    
    if os.path.exists(eeg_path):
        features = extract_eeg_features(eeg_path)
        if features:
            features['participant_id'] = subject_id
            all_subject_features.append(features)
            processed_count += 1
    else:
        # Generate synthetic features for missing files (for testing)
        features = {}
        for band in BANDS.keys():
            features[f'rbp_{band}_mean'] = np.random.random() * 0.1 + 0.1
            features[f'rbp_{band}_std'] = np.random.random() * 0.05 + 0.01
        # Add statistical features
        features['mean_across_channels'] = np.random.random() * 0.5 + 0.2
        features['std_across_channels'] = np.random.random() * 0.3 + 0.1
        features['skewness'] = np.random.normal(0, 0.5)
        features['kurtosis'] = np.random.normal(3, 0.5)
        features['participant_id'] = subject_id
        all_subject_features.append(features)
        processed_count += 1

print(f"Successfully processed {processed_count} subjects")

# Create features dataframe
features_df = pd.DataFrame(all_subject_features)
full_features_df = pd.merge(features_df, participants_df, on='participant_id', how='inner')

print("Feature extraction complete.")
print(f"Total subjects in final dataset: {len(full_features_df)}")
print("\nDataset balance:")
print(full_features_df['Group'].value_counts())

# ===================================================================
# STEP 2: DATA AUGMENTATION WITH A GAN
# ===================================================================

# Define feature columns (using mean values and statistical features for GAN)
feature_cols = [col for col in full_features_df.columns if 'rbp_' in col and '_mean' in col] + \
               ['mean_across_channels', 'std_across_channels', 'skewness', 'kurtosis']
print(f"Feature columns for GAN: {feature_cols}")

# GAN Configuration
latent_dim = 64
feature_dim = len(feature_cols)
epochs = 1000  # Reduced for faster training in Kaggle
lr = 0.0002
batch_size = 16

# Separate data by Group
ad_features = full_features_df[full_features_df['Group'] == 'A'][feature_cols].values
ftd_features = full_features_df[full_features_df['Group'] == 'F'][feature_cols].values

print(f"AD samples: {len(ad_features)}, FTD samples: {len(ftd_features)}")

# Scale features
scaler_ad = MinMaxScaler(feature_range=(-1, 1))
scaler_ftd = MinMaxScaler(feature_range=(-1, 1))

ad_features_scaled = scaler_ad.fit_transform(ad_features)
ftd_features_scaled = scaler_ftd.fit_transform(ftd_features)

class Generator(nn.Module):
    def __init__(self, latent_dim, feature_dim):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Linear(128, feature_dim),
            nn.Tanh()
        )
    
    def forward(self, z):
        return self.model(z)

class Discriminator(nn.Module):
    def __init__(self, feature_dim):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(feature_dim, 128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.3),
            
            nn.Linear(128, 64),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.3),
            
            nn.Linear(64, 32),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Linear(32, 1),
            nn.Sigmoid()
        )
    
    def forward(self, x):
        return self.model(x)

def train_gan(data_scaled, scaler, n_epochs, n_to_generate, Group_name):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Training GAN for {Group_name} on {device}")
    
    # Create dataset and dataloader
    dataset = torch.utils.data.TensorDataset(torch.FloatTensor(data_scaled))
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    
    # Initialize models
    generator = Generator(latent_dim, feature_dim).to(device)
    discriminator = Discriminator(feature_dim).to(device)
    
    # Optimizers
    g_optimizer = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
    d_optimizer = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    
    # Loss function
    criterion = nn.BCELoss()
    
    # Training loop
    g_losses = []
    d_losses = []
    
    for epoch in tqdm(range(n_epochs), desc=f"Training GAN for {Group_name}"):
        epoch_g_loss = 0
        epoch_d_loss = 0
        n_batches = 0
        
        for i, (real_samples,) in enumerate(dataloader):
            batch_size_current = real_samples.size(0)
            real_samples = real_samples.to(device)
            
            # Train Discriminator
            d_optimizer.zero_grad()
            
            # Real samples
            real_labels = torch.ones(batch_size_current, 1).to(device)
            fake_labels = torch.zeros(batch_size_current, 1).to(device)
            
            # Generate fake samples
            z = torch.randn(batch_size_current, latent_dim).to(device)
            fake_samples = generator(z).detach()
            
            # Discriminator loss
            d_loss_real = criterion(discriminator(real_samples), real_labels)
            d_loss_fake = criterion(discriminator(fake_samples), fake_labels)
            d_loss = (d_loss_real + d_loss_fake) / 2
            
            d_loss.backward()
            d_optimizer.step()
            
            # Train Generator
            g_optimizer.zero_grad()
            
            z = torch.randn(batch_size_current, latent_dim).to(device)
            fake_samples = generator(z)
            
            g_loss = criterion(discriminator(fake_samples), real_labels)
            g_loss.backward()
            g_optimizer.step()
            
            epoch_g_loss += g_loss.item()
            epoch_d_loss += d_loss.item()
            n_batches += 1
        
        if n_batches > 0:
            g_losses.append(epoch_g_loss / n_batches)
            d_losses.append(epoch_d_loss / n_batches)
        
        # Print progress every 200 epochs
        if (epoch + 1) % 200 == 0:
            print(f"Epoch [{epoch+1}/{n_epochs}] - G Loss: {g_losses[-1]:.4f}, D Loss: {d_losses[-1]:.4f}")
    
    # Generate synthetic samples
    generator.eval()
    with torch.no_grad():
        z = torch.randn(n_to_generate, latent_dim).to(device)
        synthetic_scaled = generator(z).cpu().numpy()
        synthetic_unscaled = scaler.inverse_transform(synthetic_scaled)
    
    return pd.DataFrame(synthetic_unscaled, columns=feature_cols), g_losses, d_losses

# Train GANs and generate synthetic data
print("Training GAN for AD data...")
synthetic_ad_df, ad_g_losses, ad_d_losses = train_gan(
    ad_features_scaled, scaler_ad, n_epochs=epochs, n_to_generate=60, Group_name="AD"
)
synthetic_ad_df['Group'] = 'A'

print("Training GAN for FTD data...")
synthetic_ftd_df, ftd_g_losses, ftd_d_losses = train_gan(
    ftd_features_scaled, scaler_ftd, n_epochs=epochs, n_to_generate=60, Group_name="FTD"
)
synthetic_ftd_df['Group'] = 'F'

# Combine original and synthetic data
original_data = full_features_df[feature_cols + ['Group']].copy()
augmented_features_df = pd.concat([original_data, synthetic_ad_df, synthetic_ftd_df], ignore_index=True)

print("\nOriginal dataset balance:")
print(original_data['Group'].value_counts())
print("\nAugmented dataset balance:")
print(augmented_features_df['Group'].value_counts())

# ===================================================================
# STEP 3: CNN ARCHITECTURE FOR EVALUATION
# ===================================================================

class EEGFeatureCNN(nn.Module):
    def __init__(self, input_dim, num_classes=2):
        super(EEGFeatureCNN, self).__init__()
        
        # Reshape input to simulate 1D CNN on features
        self.input_dim = input_dim
        
        # 1D CNN layers
        self.conv1 = nn.Conv1d(1, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm1d(32)
        self.conv2 = nn.Conv1d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm1d(64)
        self.conv3 = nn.Conv1d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm1d(128)
        
        # Global pooling
        self.global_pool = nn.AdaptiveAvgPool1d(1)
        
        # Fully connected layers
        self.fc1 = nn.Linear(128, 64)
        self.dropout1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(64, 32)
        self.dropout2 = nn.Dropout(0.3)
        self.fc3 = nn.Linear(32, num_classes)
        
    def forward(self, x):
        # Reshape for CNN: (batch_size, 1, features)
        x = x.view(x.size(0), 1, -1)
        
        # CNN layers
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        
        # Global pooling
        x = self.global_pool(x)
        x = x.view(x.size(0), -1)
        
        # Fully connected layers
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        x = self.fc3(x)
        
        return x
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 107.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 92.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.3/128.3 kB 8.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.40.1 which is incompatible.
# bigframes 1.42.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.2.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 3.4 MB/s eta 0:00:00
# Loaded 88 participants
# Processing EEG files:   0%|          | 0/88 [00:00<?, ?it/s]
# Successfully processed 88 subjects
# Feature extraction complete.
# Total subjects in final dataset: 88
#
# Dataset balance:
# Group
# A    36
# C    29
# F    23
# Name: count, dtype: int64
# Feature columns for GAN: ['rbp_delta_mean', 'rbp_theta_mean', 'rbp_alpha_mean', 'rbp_beta_mean', 'rbp_gamma_mean', 'mean_across_channels', 'std_across_channels', 'skewness', 'kurtosis']
# AD samples: 36, FTD samples: 23
# Training GAN for AD data...
# Training GAN for AD on cuda
# Training GAN for AD:   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch [200/1000] - G Loss: 0.6607, D Loss: 0.6943
# Epoch [400/1000] - G Loss: 0.6705, D Loss: 0.6998
# Epoch [600/1000] - G Loss: 0.7361, D Loss: 0.6752
# Epoch [800/1000] - G Loss: 0.7119, D Loss: 0.6792
# Epoch [1000/1000] - G Loss: 0.7109, D Loss: 0.6719
# Training GAN for FTD data...
# Training GAN for FTD on cuda
# Training GAN for FTD:   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch [200/1000] - G Loss: 0.7234, D Loss: 0.6819
# Epoch [400/1000] - G Loss: 0.7336, D Loss: 0.6905
# Epoch [600/1000] - G Loss: 0.6769, D Loss: 0.6811
# Epoch [800/1000] - G Loss: 0.6666, D Loss: 0.6846
# Epoch [1000/1000] - G Loss: 0.7340, D Loss: 0.6782
#
# Original dataset balance:
# Group
# A    36
# C    29
# F    23
# Name: count, dtype: int64
#
# Augmented dataset balance:
# Group
# A    96
# F    83
# C    29
# Name: count, dtype: int64

# %%
def evaluate_model(features_df, model_name, test_size=0.2):
    """Train and evaluate CNN model on given features"""
    print(f"\n=== Evaluating {model_name} ===")
    
    # Prepare data
    X = features_df[feature_cols].values
    y = features_df['Group'].values
    
    # Encode labels
    # ✅ FIX: Explicitly map 'A' → 0, 'F' → 1 (avoid extra classes)
    y_encoded = np.where(y == 'A', 0, 1)
    
    # Print unique labels to verify
    print(f"Unique labels found: {np.unique(y_encoded)}")
    print(f"Label distribution: {np.bincount(y_encoded)}")
    
    # Scale features
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Split data
    X_train, X_test, y_train, y_test = train_test_split(
        X_scaled, y_encoded, test_size=test_size, random_state=42, stratify=y_encoded
    )
    
    # Convert to tensors
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    X_train_tensor = torch.FloatTensor(X_train).to(device)
    X_test_tensor = torch.FloatTensor(X_test).to(device)
    y_train_tensor = torch.LongTensor(y_train).to(device)
    y_test_tensor = torch.LongTensor(y_test).to(device)
    
    # Verify tensor values
    print(f"Training labels min: {y_train_tensor.min().item()}, max: {y_train_tensor.max().item()}")
    
    # Initialize model
    model = EEGFeatureCNN(input_dim=len(feature_cols), num_classes=2).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)
    
    # Training
    model.train()
    train_losses = []
    train_accuracies = []
    
    epochs = 100
    for epoch in range(epochs):
        optimizer.zero_grad()
        outputs = model(X_train_tensor)
        
        # Verify outputs and targets
        print(f"Output shape: {outputs.shape}, Target shape: {y_train_tensor.shape}")
        print(f"Output range: {outputs.min().item():.4f} to {outputs.max().item():.4f}")
        
        loss = criterion(outputs, y_train_tensor)
        loss.backward()
        optimizer.step()
        scheduler.step()
        
        # Calculate training accuracy
        _, predicted = torch.max(outputs.data, 1)
        train_acc = (predicted == y_train_tensor).float().mean().item()
        
        train_losses.append(loss.item())
        train_accuracies.append(train_acc)
        
        if (epoch + 1) % 20 == 0:
            print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}, Train Acc: {train_acc:.4f}')
    
    # Evaluation
    model.eval()
    with torch.no_grad():
        test_outputs = model(X_test_tensor)
        _, test_predicted = torch.max(test_outputs.data, 1)
        test_accuracy = (test_predicted == y_test_tensor).float().mean().item()
    
    # Convert predictions back to CPU for sklearn metrics
    y_test_np = y_test_tensor.cpu().numpy()
    test_predicted_np = test_predicted.cpu().numpy()

    # import numpy as np
    print(f"\n{model_name} Results:")
    print(f"Test Accuracy: {test_accuracy:.4f}")
    print(f"Classification Report:")
    print("\nClassification Report:")
    # np.set_printoptions(linewidth=120)  # Prevent line wrapping
    print(classification_report(
            y_test_np, 
            test_predicted_np, 
            target_names=['A', 'F']  # Manually set class names
            ))
    
    return test_accuracy, train_losses, train_accuracies

# %%
print("Unique Groups:", original_data['Group'].unique())
# Out:
# Unique Groups: ['A' 'C' 'F']

# %%
print("NaN in labels:", original_data['Group'].isna().sum())
# Out:
# NaN in labels: 0

# %%
print("\nOriginal dataset balance:")
print(original_data)
print("\n")
print("\nAugmented dataset balance:")
print(augmented_features_df)
# Out:
# Original dataset balance:
#     rbp_delta_mean  rbp_theta_mean  rbp_alpha_mean  rbp_beta_mean  \
# 0         0.843870        0.049166        0.013220       0.010913
# 1         0.819422        0.046118        0.036199       0.014257
# 2         0.782933        0.071658        0.056393       0.013678
# 3         0.832697        0.043093        0.011955       0.013090
# 4         0.835100        0.041824        0.014054       0.012911
# ..             ...             ...             ...            ...
# 83        0.815327        0.056468        0.016671       0.016030
# 84        0.753652        0.052193        0.013170       0.009541
# 85        0.814778        0.014910        0.008039       0.020850
# 86        0.851732        0.041396        0.015496       0.010198
# 87        0.815160        0.047587        0.031020       0.017810
#
#     rbp_gamma_mean  mean_across_channels  std_across_channels  skewness  \
# 0         0.003945              0.051639             8.601401  0.070209
# 1         0.004291              0.038543             7.929008  0.045665
# 2         0.002903             -0.086899             7.952449  0.086583
# 3         0.007497             -0.015920             9.869505  0.413152
# 4         0.004927              0.019694            11.324293  0.111103
# ..             ...                   ...                  ...       ...
# 83        0.006351              0.006358             8.820041 -0.051179
# 84        0.007951              0.083179            22.090439 -0.595524
# 85        0.018608             -0.052112            65.009762 -0.062505
# 86        0.002251             -0.053512            13.570023  0.140259
# 87        0.004701              0.040380             9.306476  0.000510
#
#      kurtosis Group
# 0    5.375826     A
# 1    3.125504     A
# 2    3.021905     A
# 3   14.925384     A
# 4    6.934592     A
# ..        ...   ...
# 83   3.106702     F
# 84  81.728215     F
# 85   5.678957     F
# 86   3.897878     F
# 87   3.845887     F
#
# [88 rows x 10 columns]
#
#
#
# Augmented dataset balance:
#      rbp_delta_mean  rbp_theta_mean  rbp_alpha_mean  rbp_beta_mean  \
# 0          0.843870        0.049166        0.013220       0.010913
# 1          0.819422        0.046118        0.036199       0.014257
# 2          0.782933        0.071658        0.056393       0.013678
# 3          0.832697        0.043093        0.011955       0.013090
# 4          0.835100        0.041824        0.014054       0.012911
# ..              ...             ...             ...            ...
# 203        0.761355        0.061059        0.045128       0.014803
# 204        0.760488        0.069398        0.044901       0.039419
# 205        0.772248        0.058541        0.042956       0.033646
# 206        0.842255        0.030192        0.009807       0.020902
# 207        0.753093        0.086768        0.049841       0.043498
#
#      rbp_gamma_mean  mean_across_channels  std_across_channels  skewness  \
# 0          0.003945              0.051639             8.601401  0.070209
# 1          0.004291              0.038543             7.929008  0.045665
# 2          0.002903             -0.086899             7.952449  0.086583
# 3          0.007497             -0.015920             9.869505  0.413152
# 4          0.004927              0.019694            11.324293  0.111103
# ..              ...                   ...                  ...       ...
# 203        0.003099              0.010656             6.738868 -0.029410
# 204        0.008813             -0.032909             7.030169  0.775899
# 205        0.007015             -0.044986             6.754532  0.356639
# 206        0.022562             -0.046154            13.901540  0.405085
# 207        0.007231             -0.026336             6.428520  0.435221
#
#        kurtosis Group
# 0      5.375826     A
# 1      3.125504     A
# 2      3.021905     A
# 3     14.925384     A
# 4      6.934592     A
# ..          ...   ...
# 203    2.987740     F
# 204  191.202026     F
# 205    6.127478     F
# 206    4.375173     F
# 207   56.954227     F
#
# [208 rows x 10 columns]

# %%
# ===================================================================
# STEP 4: EVALUATION AND COMPARISON
# ===================================================================

# Evaluate original data
original_accuracy, orig_losses, orig_train_acc = evaluate_model(original_data, "Original Data")

# Evaluate augmented data
augmented_accuracy, aug_losses, aug_train_acc = evaluate_model(augmented_features_df, "Augmented Data")
# Out:
# === Evaluating Original Data ===
# Unique labels found: [0 1]
# Label distribution: [36 52]
# Training labels min: 0, max: 1
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.2617 to 0.1397
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.2391 to 0.1373
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.4170 to 0.1533
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.3329 to 0.2106
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.5378 to 0.2070
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.0077 to 0.2494
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.3888 to 0.2812
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.4303 to 0.4078
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.7292 to 0.3292
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.6843 to 0.4655
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.5412 to 0.3899
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.5484 to 0.4204
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.5679 to 0.4487
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.7050 to 0.6935
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.7776 to 0.6303
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.6843 to 0.6903
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.6423 to 0.6458
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.7866 to 0.7075
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.9044 to 0.8274
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.8202 to 0.6625
# Epoch [20/100], Loss: 0.6648, Train Acc: 0.6143
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.8723 to 0.6177
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.7317 to 0.6179
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.6534 to 0.4450
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.9586 to 0.8531
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.7462 to 0.7412
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.7375 to 0.6931
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.7791 to 0.6256
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.7806 to 0.6329
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.9365 to 0.7092
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.9006 to 0.8941
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.7557 to 0.7089
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.8435 to 0.8435
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.0497 to 0.9176
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.8160 to 0.7374
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.1636 to 0.8753
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.0219 to 1.0293
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.1487 to 1.0554
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.0584 to 0.8559
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -0.8947 to 0.7377
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.0440 to 0.8270
# Epoch [40/100], Loss: 0.5674, Train Acc: 0.7429
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.1236 to 0.8399
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.3229 to 1.0480
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.1863 to 0.9387
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.0759 to 1.0681
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.4563 to 1.1650
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.6980 to 1.6071
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.6869 to 1.3673
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.0161 to 1.5963
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.9760 to 1.6412
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.8447 to 1.5647
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.9323 to 2.8462
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.7493 to 1.1950
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.6332 to 1.5852
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.6738 to 1.5965
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.7533 to 1.5483
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.5651 to 1.4811
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.0478 to 1.7078
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.3099 to 2.3869
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.9306 to 1.9468
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.0500 to 2.0506
# Epoch [60/100], Loss: 0.4674, Train Acc: 0.7714
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.3290 to 2.7385
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.0805 to 1.6734
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.2986 to 2.4457
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.9838 to 2.0295
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.8284 to 1.8212
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.3907 to 2.2304
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.6082 to 1.8425
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.3160 to 2.3092
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.9171 to 1.7776
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.7751 to 2.0910
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -3.0741 to 1.7433
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.8492 to 2.0700
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.6544 to 1.3749
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -1.8383 to 1.3741
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.0462 to 1.5636
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.9181 to 1.7833
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.7681 to 2.5965
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.2749 to 2.0440
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.9433 to 2.7933
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.1187 to 2.4062
# Epoch [80/100], Loss: 0.3793, Train Acc: 0.8857
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -3.1796 to 2.0634
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.4611 to 2.5464
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.5646 to 2.6633
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.6859 to 2.9289
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.4937 to 1.9560
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.7590 to 2.8879
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.7758 to 2.6951
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.2196 to 2.4890
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.1557 to 2.1197
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.8646 to 1.7069
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.7281 to 2.1487
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -3.0610 to 2.9067
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.7620 to 2.6869
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.1723 to 1.6076
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.9757 to 1.9341
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -3.2454 to 2.5284
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.3889 to 2.3239
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.2215 to 1.9896
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.0101 to 2.0706
# Output shape: torch.Size([70, 2]), Target shape: torch.Size([70])
# Output range: -2.5221 to 2.3470
# Epoch [100/100], Loss: 0.3835, Train Acc: 0.9000
#
# Original Data Results:
# Test Accuracy: 0.5000
# Classification Report:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            A       0.25      0.14      0.18         7
#            F       0.57      0.73      0.64        11
#
#     accuracy                           0.50        18
#    macro avg       0.41      0.44      0.41        18
# weighted avg       0.45      0.50      0.46        18
#
#
# === Evaluating Augmented Data ===
# Unique labels found: [0 1]
# Label distribution: [ 96 112]
# Training labels min: 0, max: 1
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -0.4344 to 0.0018
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -0.4591 to 0.0673
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -0.5461 to 0.0150
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -0.4454 to 0.2113
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -0.3937 to 0.0307
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -0.5910 to 0.0407
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -0.7422 to 0.4144
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -0.4841 to 0.2187
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.0324 to 0.1711
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -0.8356 to 0.6378
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.1349 to 0.4344
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.3860 to 0.4819
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -0.8821 to 0.5155
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.0232 to 1.5104
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.1291 to 0.5581
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.4064 to 0.7128
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.0232 to 0.7507
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.2711 to 0.9969
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.3579 to 0.7608
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.5817 to 1.0090
# Epoch [20/100], Loss: 0.6287, Train Acc: 0.6928
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -2.1068 to 0.7822
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.3308 to 0.9024
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.6096 to 1.1383
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.6180 to 1.1578
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.4679 to 0.8630
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.6385 to 0.9740
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.7830 to 0.8717
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.8550 to 1.4172
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -2.4327 to 1.0635
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -2.1831 to 1.8600
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -2.4925 to 1.7371
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -2.7184 to 2.0419
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -1.8814 to 1.4299
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -2.5822 to 1.6365
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.0061 to 2.0928
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -3.4344 to 2.4850
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -2.9190 to 2.3520
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.1683 to 3.3807
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.5610 to 2.6369
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.9378 to 2.1261
# Epoch [40/100], Loss: 0.4693, Train Acc: 0.8133
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -3.2063 to 2.9755
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.8109 to 5.2654
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -3.8880 to 2.8440
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -2.9709 to 2.8534
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.7599 to 2.9009
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.3016 to 2.9530
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.9764 to 3.1899
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.3344 to 3.5237
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.0149 to 3.0402
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.8093 to 5.0873
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.2891 to 2.9807
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.4355 to 3.5938
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.5369 to 4.2509
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.2543 to 3.4606
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.8493 to 3.1821
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.6257 to 3.9632
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.7854 to 4.8644
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.0192 to 3.3425
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.4018 to 4.7611
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -7.8374 to 6.5908
# Epoch [60/100], Loss: 0.3633, Train Acc: 0.8373
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.4260 to 3.7070
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.9431 to 3.6877
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.5356 to 4.9164
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.2567 to 2.8320
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.2738 to 4.2567
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.2704 to 3.4905
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.8197 to 3.3872
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.5242 to 4.0405
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.8549 to 3.7463
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.7927 to 3.8335
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.5743 to 5.6075
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.9975 to 5.6255
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -3.5897 to 3.7565
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.3814 to 4.0718
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.7409 to 3.0093
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.6158 to 4.4906
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.1968 to 3.9460
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.7460 to 4.7282
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.6668 to 4.4461
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.5535 to 3.8531
# Epoch [80/100], Loss: 0.3346, Train Acc: 0.8855
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.5935 to 3.7034
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.2663 to 3.2576
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.2856 to 4.5051
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.2520 to 3.7029
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.5768 to 4.3245
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.8230 to 3.4259
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.5898 to 3.6568
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.2711 to 4.8784
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -7.5472 to 4.1384
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.7586 to 5.1023
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -7.8360 to 4.4545
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.7281 to 3.9781
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -7.3100 to 3.7824
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -4.5785 to 3.4580
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.4578 to 5.3470
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -5.5452 to 3.9631
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -7.5918 to 3.7697
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.5017 to 5.0771
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.7975 to 4.0079
# Output shape: torch.Size([166, 2]), Target shape: torch.Size([166])
# Output range: -6.7830 to 5.4645
# Epoch [100/100], Loss: 0.2705, Train Acc: 0.8976
#
# Augmented Data Results:
# Test Accuracy: 0.8333
# Classification Report:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            A       0.80      0.84      0.82        19
#            F       0.86      0.83      0.84        23
#
#     accuracy                           0.83        42
#    macro avg       0.83      0.83      0.83        42
# weighted avg       0.83      0.83      0.83        42

# %%
# ===================================================================
# STEP 5: VISUALIZATION
# ===================================================================

# Plot training losses for GANs
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# GAN losses
axes[0, 0].plot(ad_g_losses, label='Generator')
axes[0, 0].plot(ad_d_losses, label='Discriminator')
axes[0, 0].set_title('AD GAN Training Losses')
axes[0, 0].legend()
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss')

axes[0, 1].plot(ftd_g_losses, label='Generator')
axes[0, 1].plot(ftd_d_losses, label='Discriminator')
axes[0, 1].set_title('FTD GAN Training Losses')
axes[0, 1].legend()
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Loss')

# CNN training losses
axes[1, 0].plot(orig_losses, label='Original Data')
axes[1, 0].plot(aug_losses, label='Augmented Data')
axes[1, 0].set_title('CNN Training Losses')
axes[1, 0].legend()
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Loss')

# CNN training accuracies
axes[1, 1].plot(orig_train_acc, label='Original Data')
axes[1, 1].plot(aug_train_acc, label='Augmented Data')
axes[1, 1].set_title('CNN Training Accuracies')
axes[1, 1].legend()
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('Accuracy')

plt.tight_layout()
plt.savefig('/kaggle/working/training_curves.png', dpi=150, bbox_inches='tight')
plt.show()

# Compare feature distributions
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

for i, feature in enumerate(feature_cols[:6]):  # Plot first 6 features
    # Original data
    ad_orig = original_data[original_data['Group'] == 'A'][feature]
    ftd_orig = original_data[original_data['Group'] == 'F'][feature]
    
    # Synthetic data
    ad_synth = synthetic_ad_df[feature]
    ftd_synth = synthetic_ftd_df[feature]
    
    axes[i].hist(ad_orig, alpha=0.5, label='AD Original', bins=20, density=True)
    axes[i].hist(ftd_orig, alpha=0.5, label='FTD Original', bins=20, density=True)
    axes[i].hist(ad_synth, alpha=0.5, label='AD Synthetic', bins=20, density=True, histtype='step')
    axes[i].hist(ftd_synth, alpha=0.5, label='FTD Synthetic', bins=20, density=True, histtype='step')
    axes[i].set_title(f'{feature}')
    axes[i].legend()

plt.tight_layout()
plt.savefig('/kaggle/working/feature_distributions.png', dpi=150, bbox_inches='tight')
plt.show()

# Summary
print("\n" + "="*60)
print("FINAL RESULTS SUMMARY")
print("="*60)
print(f"Original Data Test Accuracy: {original_accuracy:.4f}")
print(f"Augmented Data Test Accuracy: {augmented_accuracy:.4f}")
print(f"Improvement: {augmented_accuracy - original_accuracy:.4f}")
print("="*60)

# Save results
results = {
    'original_accuracy': original_accuracy,
    'augmented_accuracy': augmented_accuracy,
    'improvement': augmented_accuracy - original_accuracy,
    'original_samples': len(original_data),
    'augmented_samples': len(augmented_features_df)
}

with open('/kaggle/working/results.json', 'w') as f:
    json.dump(results, f, indent=2)

print("Results saved to /kaggle/working/results.json")
print("Training curves saved to /kaggle/working/training_curves.png")
print("Feature distributions saved to /kaggle/working/feature_distributions.png")
# Out:
# ============================================================
# FINAL RESULTS SUMMARY
# ============================================================
# Original Data Test Accuracy: 0.5000
# Augmented Data Test Accuracy: 0.8333
# Improvement: 0.3333
# ============================================================
# Results saved to /kaggle/working/results.json
# Training curves saved to /kaggle/working/training_curves.png
# Feature distributions saved to /kaggle/working/feature_distributions.png

# %%
# ===================================================================
# STEP 6: TEXTUAL CORPUS GENERATION
# ===================================================================

def generate_text_report_deepseek(feature_row):
    """Generate clinical-style EEG analysis reports for LLM training"""
    diagnosis_map = {'A': "Alzheimer's Disease", 'F': 'Frontotemporal Dementia', 'C': 'Healthy Control'}
    diagnosis = diagnosis_map.get(feature_row['Group'], 'Unknown')
    
    report_parts = []
    
    # Safely calculate theta/alpha ratio
    theta_alpha_ratio = 0.0
    if feature_row['rbp_alpha_mean'] > 1e-6:  # Avoid division by near-zero
        theta_alpha_ratio = feature_row['rbp_theta_mean'] / feature_row['rbp_alpha_mean']
    
    # Analyze theta/alpha ratio
    if theta_alpha_ratio > 1.2 and diagnosis != 'Healthy Control':
        report_parts.append(f"a notably elevated theta/alpha power ratio of {theta_alpha_ratio:.2f}, indicating significant slowing of brain activity")
    elif theta_alpha_ratio > 0.8:
        report_parts.append(f"a moderately elevated theta/alpha power ratio of {theta_alpha_ratio:.2f}, suggesting mild cognitive changes")
    else:
        report_parts.append(f"a theta/alpha power ratio of {theta_alpha_ratio:.2f} within expected ranges")

    # Analyze statistical features with safety checks
    mean_amp = feature_row.get('mean_across_channels', 0)
    if mean_amp < 0.2 and diagnosis != 'Healthy Control':
        report_parts.append(f"reduced mean signal amplitude ({mean_amp:.3f} µV), indicating possible neural dysfunction")
    else:
        report_parts.append(f"mean signal amplitude of {mean_amp:.3f} µV")
    
    # Analyze frequency band patterns
    if 'rbp_delta_mean' in feature_row and 'rbp_alpha_mean' in feature_row:
        if feature_row['rbp_delta_mean'] > feature_row['rbp_alpha_mean'] and diagnosis != 'Healthy Control':
            report_parts.append("dominance of delta band activity over alpha rhythms, characteristic of pathological brain states")
    
    if abs(feature_row.get('skewness', 0)) > 1.0:
        report_parts.append(f"abnormal signal distribution (skewness: {feature_row['skewness']:.2f})")
    
    reasoning_text = ", ".join(report_parts)
    
    # Create clinical assessment prompt
    prompt = (f"Analyze these resting-state EEG biomarkers and provide a clinical assessment:\n\n"
              f"- Theta/Alpha Ratio: {theta_alpha_ratio:.2f}\n"
              f"- Delta Power: {feature_row.get('rbp_delta_mean', 0):.3f}\n"
              f"- Theta Power: {feature_row.get('rbp_theta_mean', 0):.3f}\n"
              f"- Alpha Power: {feature_row.get('rbp_alpha_mean', 0):.3f}\n"
              f"- Beta Power: {feature_row.get('rbp_beta_mean', 0):.3f}\n"
              f"- Gamma Power: {feature_row.get('rbp_gamma_mean', 0):.3f}\n"
              f"- Mean Amplitude: {mean_amp:.3f} µV\n"
              f"- Signal Variability: {feature_row.get('std_across_channels', 0):.3f}\n"
              f"- Skewness: {feature_row.get('skewness', 0):.2f}\n"
              f"- Kurtosis: {feature_row.get('kurtosis', 0):.2f}")
    
    # Generate clinical response
    completion = (f"The patient demonstrates {reasoning_text}. These findings are "
                 f"{'consistent with' if diagnosis != 'Unknown' else 'suggestive of'} "
                 f"{diagnosis}. The pattern suggests "
                 f"{'neurodegenerative changes' if diagnosis != 'Healthy Control' else 'normal brain activity'}.")
    
    return {'text': f"User: {prompt}\n\nAssistant: {completion}"}

# Generate text corpus from augmented data
print("\nGenerating textual corpus for LLM training...")
text_corpus = []

for index, row in tqdm(augmented_features_df.iterrows(), total=len(augmented_features_df), desc="Generating reports"):
    try:
        report = generate_text_report_deepseek(row)
        text_corpus.append(report)
    except Exception as e:
        print(f"Error generating report for row {index}: {e}")
        continue

# Save the corpus
corpus_path = '/kaggle/working/eeg_deepseek_finetuning_corpus.jsonl'
try:
    with open(corpus_path, 'w') as f:
        for item in text_corpus:
            f.write(json.dumps(item) + '\n')
    print(f"✅ Generated {len(text_corpus)} reports saved to {corpus_path}")
except Exception as e:
    print(f"❌ Error saving corpus: {e}")

# Display sample
if text_corpus:
    print("\n--- Sample Report ---")
    print(text_corpus[0]['text'][:500] + "...")
# Out:
# Generating textual corpus for LLM training...
# Generating reports:   0%|          | 0/208 [00:00<?, ?it/s]
# ✅ Generated 208 reports saved to /kaggle/working/eeg_deepseek_finetuning_corpus.jsonl
#
# --- Sample Report ---
# User: Analyze these resting-state EEG biomarkers and provide a clinical assessment:
#
# - Theta/Alpha Ratio: 3.72
# - Delta Power: 0.844
# - Theta Power: 0.049
# - Alpha Power: 0.013
# - Beta Power: 0.011
# - Gamma Power: 0.004
# - Mean Amplitude: 0.052 µV
# - Signal Variability: 8.601
# - Skewness: 0.07
# - Kurtosis: 5.38
#
# Assistant: The patient demonstrates a notably elevated theta/alpha power ratio of 3.72, indicating significant slowing of brain activity, reduced mean signal amplitude (0.052 µV), indicating poss...

# %%
# !pip install -q "triton==2.3.0"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 10.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires triton==3.2.0; platform_system == "Linux" and platform_machine == "x86_64", but you have triton 2.3.0 which is incompatible.

# %%
# ===================================================================
# STEP 7: DEEPSEEK LLM FINE-TUNING (bfloat16, no bitsandbytes)
# ===================================================================

import os
import torch

def check_system_resources():
    """Check available system resources"""
    try:
        import psutil
        memory = psutil.virtual_memory()
        disk = psutil.disk_usage('/kaggle/working')
        
        print(f"\nSystem Resources:")
        print(f"Available RAM: {memory.available / (1024**3):.1f} GB")
        print(f"Available Disk: {disk.free / (1024**3):.1f} GB")
        
        return memory.available > 4 * (1024**3) and disk.free > 2 * (1024**3)
    except ImportError:
        print("⚠️ psutil not available, proceeding with caution")
        return True

try:
    from transformers import (
        AutoModelForCausalLM, 
        AutoTokenizer, 
        TrainingArguments
    )
    from datasets import Dataset
    from peft import LoraConfig, get_peft_model
    from trl import SFTTrainer
    
    # Check resources
    can_proceed = check_system_resources()
    
    if can_proceed and len(text_corpus) >= 20:
        print("\n🚀 Starting DeepSeek fine-tuning...")
        
        # Model & output paths
        model_name = "deepseek-ai/deepseek-llm-7b-chat"
        new_model_dir = "/kaggle/working/Neuro-DeepSeek-7B"
        
        # LoRA config
        lora_config = LoraConfig(
            r=8,
            lora_alpha=16,
            lora_dropout=0.05,
            bias="none",
            task_type="CAUSAL_LM",
            target_modules=['q_proj', 'k_proj', 'v_proj', 'o_proj']
        )
        
        # Load base model in bfloat16
        print("Loading model in bfloat16…")
        model = AutoModelForCausalLM.from_pretrained(
            model_name,
            torch_dtype=torch.bfloat16,
            device_map="auto",
            use_auth_token=os.environ.get('HF_TOKEN')
        )
        model.config.use_cache = False
        
        # Apply LoRA
        model = get_peft_model(model, lora_config)
        trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
        print(f"Trainable params: {trainable:,}")
        
        # Tokenizer
        tokenizer = AutoTokenizer.from_pretrained(
            model_name,
            use_auth_token=os.environ.get('HF_TOKEN'),
            padding_side="right"
        )
        tokenizer.pad_token = tokenizer.eos_token
        
        # Prepare dataset
        dataset = Dataset.from_dict({"text": [item["text"] for item in text_corpus]})
        
        # Training args
        training_args = TrainingArguments(
            output_dir="/kaggle/working/results",
            num_train_epochs=1,
            per_device_train_batch_size=1,
            gradient_accumulation_steps=4,
            learning_rate=2e-5,
            optim="adamw_torch",
            bf16=True,
            max_steps=50,
            logging_steps=5,
            save_steps=25,
            report_to=[],
            remove_unused_columns=False
        )
        
        # Trainer
        trainer = SFTTrainer(
            model=model,
            train_dataset=dataset,
            peft_config=lora_config,
            dataset_text_field="text",
            max_seq_length=384,
            tokenizer=tokenizer,
            args=training_args,
        )
        
        # Train
        print("Starting training…")
        trainer.train()
        
        # Save
        trainer.model.save_pretrained(new_model_dir)
        tokenizer.save_pretrained(new_model_dir)
        print(f"✅ Saved to {new_model_dir}")
        
        # Quick test
        test_prompt = (
            "User: Analyze EEG with theta/alpha ratio of 1.8 and delta power of 0.3\n\nAssistant:"
        )
        inputs = tokenizer(test_prompt, return_tensors="pt").to(model.device)
        outputs = model.generate(
            **inputs,
            max_new_tokens=100,
            temperature=0.7
        )
        print("\nTest Inference:")
        print(tokenizer.decode(outputs[0], skip_special_tokens=True))
        
    else:
        print("⚠️ Insufficient resources or data for fine-tuning")
        
except ImportError as e:
    print(f"❌ Missing libraries: {e}")
except Exception as e:
    print(f"❌ Unexpected error: {e}")
# Out:
# ❌ Unexpected error: [Errno 2] No such file or directory: '/usr/local/lib/python3.11/dist-packages/triton/backends/nvidia/driver.c'
